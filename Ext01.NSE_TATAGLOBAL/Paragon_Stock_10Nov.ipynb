# %% [markdown]
# #Import data and library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import matplotlib.dates as mates
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.models import Sequential #helps to create model, layer by layer.
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error
# Out:
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Replace 'your_file_path.csv' with the path to your local CSV file
dataset_train = pd.read_csv('NSE-TATAGLOBAL.csv')
#stock_data = dataset_train.iloc[:, 1:2].values

# %% [markdown]
# #Data analytic

# %%
dataset_train.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
training_data = dataset_train.iloc[:, 5:6]
training_data.head()
# Out:
#     Close
# 0  233.75
# 1  233.25
# 2  234.25
# 3  236.10
# 4  233.30

# %%
import matplotlib.pylab as plt
plt.figure(figsize=(10,5))
plt.plot(training_data, color ='green');
plt.ylabel('Stock Price')
plt.title('Random Stock Price')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# #Min Max Scaler

# %%
# Normalize the training data between [0,1]
#the fit method, when applied to the training dataset, learns the model parameters (for example, mean and standard deviation).
#We then need to apply the transform method on the training dataset to get the transformed (scaled) training dataset.
#We could also perform both of this step in one step by applying fit_transform on the training dataset.
mm = MinMaxScaler(feature_range = (0, 1))
training_data_scaled = mm.fit_transform(training_data)
training_data_scaled.shape
# Out:
# (2035, 1)

# %%
plt.figure(figsize=(10,5))
plt.plot(training_data_scaled)
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.show()

# %% [markdown]
# #Prepare data for model training

# %%
# Getting the inputs and outputs directly if you know how to consider the past data for the number of time stamps needed for RNN.
x_train = training_data_scaled[59:training_data_scaled.shape[0]-1-365]
y_train = training_data_scaled[60:training_data_scaled.shape[0]-365]
x_test = training_data_scaled[training_data_scaled.shape[0]-1-365:-1]
y_test = training_data_scaled[training_data_scaled.shape[0]-365:]
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1610, 1)
# (1610, 1)
# (365, 1)
# (365, 1)

# %%
# reshaping
x_train = np.reshape(x_train, (x_train.shape[0],1,1))
print(x_train.shape)
# Out:
# (1610, 1, 1)

# %% [markdown]
# #Model Creation

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50,return_sequences = True,input_shape = (x_train.shape[1],1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
regressor.compile(optimizer = 'adam',loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
regressor.fit(x_train,y_train,epochs = 200, batch_size = 32)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 51/51 [==============================] - 7s 6ms/step - loss: 0.0710
# Epoch 2/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0230
# Epoch 3/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 4/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 5/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 6/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0025
# Epoch 7/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 8/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 9/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 10/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 11/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 12/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 13/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 14/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 15/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 16/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 17/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 18/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 19/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 20/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 21/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 22/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 23/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 24/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 25/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 26/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 27/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 28/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 29/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 30/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 31/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 32/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 33/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 34/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.9288e-04
# Epoch 35/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 36/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 37/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.9245e-04
# Epoch 38/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 39/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 40/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.6466e-04
# Epoch 41/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.8758e-04
# Epoch 42/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 43/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.9798e-04
# Epoch 44/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 45/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 46/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.1217e-04
# Epoch 47/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.3602e-04
# Epoch 48/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 49/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.7379e-04
# Epoch 50/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.6335e-04
# Epoch 51/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.0419e-04
# Epoch 52/200
# 51/51 [==============================] - 0s 6ms/step - loss: 8.9844e-04
# Epoch 53/200
# 51/51 [==============================] - 0s 6ms/step - loss: 9.6273e-04
# Epoch 54/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.9760e-04
# Epoch 55/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.6222e-04
# Epoch 56/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.8908e-04
# Epoch 57/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.0684e-04
# Epoch 58/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.8185e-04
# Epoch 59/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.9523e-04
# Epoch 60/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5690e-04
# Epoch 61/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.3012e-04
# Epoch 62/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.4966e-04
# Epoch 63/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.2140e-04
# Epoch 64/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.6833e-04
# Epoch 65/200
# 51/51 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch
200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.1290e-04
# Epoch 138/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.5220e-04
# Epoch 139/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.2486e-04
# Epoch 140/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.6400e-04
# Epoch 141/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.6155e-04
# Epoch 142/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.9248e-04
# Epoch 143/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3178e-04
# Epoch 144/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3587e-04
# Epoch 145/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.1227e-04
# Epoch 146/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.8475e-04
# Epoch 147/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.8075e-04
# Epoch 148/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.0485e-04
# Epoch 149/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.2122e-04
# Epoch 150/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.6827e-04
# Epoch 151/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3744e-04
# Epoch 152/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.8864e-04
# Epoch 153/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.0027e-04
# Epoch 154/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.3847e-04
# Epoch 155/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.8102e-04
# Epoch 156/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.7027e-04
# Epoch 157/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.4065e-04
# Epoch 158/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.5401e-04
# Epoch 159/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.1334e-04
# Epoch 160/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.8914e-04
# Epoch 161/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.7158e-04
# Epoch 162/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.7519e-04
# Epoch 163/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.5893e-04
# Epoch 164/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3693e-04
# Epoch 165/200
# 51/51 [==============================] - 0s 7ms/step - loss: 7.4811e-04
# Epoch 166/200
# 51/51 [==============================] - 0s 6ms/step - loss: 7.5962e-04
# Epoch 167/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.0567e-04
# Epoch 168/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.3283e-04
# Epoch 169/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.7551e-04
# Epoch 170/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.1466e-04
# Epoch 171/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3950e-04
# Epoch 172/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.2970e-04
# Epoch 173/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.3793e-04
# Epoch 174/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.9324e-04
# Epoch 175/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.7050e-04
# Epoch 176/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.0552e-04
# Epoch 177/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.9687e-04
# Epoch 178/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.2612e-04
# Epoch 179/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.9919e-04
# Epoch 180/200
# 51/51 [==============================] - 0s 6ms/step - loss: 7.2578e-04
# Epoch 181/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.6515e-04
# Epoch 182/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3919e-04
# Epoch 183/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.0251e-04
# Epoch 184/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.9833e-04
# Epoch 185/200
# 51/51 [==============================] - 0s 4ms/step - loss: 8.8338e-04
# Epoch 186/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3128e-04
# Epoch 187/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.2670e-04
# Epoch 188/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.1076e-04
# Epoch 189/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.9323e-04
# Epoch 190/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.8456e-04
# Epoch 191/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.1109e-04
# Epoch 192/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.9185e-04
# Epoch 193/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.8135e-04
# Epoch 194/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3436e-04
# Epoch 195/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3847e-04
# Epoch 196/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.4502e-04
# Epoch 197/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.7147e-04
# Epoch 198/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5251e-04
# Epoch 199/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.2518e-04
# Epoch 200/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.7262e-04

# %% [markdown]
# #Prediction and Evaluation

# %%
input_value = np.reshape(x_test, (x_test.shape[0], 1, 1))

# %%
prediction = regressor.predict(input_value)
prediction = mm.inverse_transform(prediction)
y_test_inverse = mm.inverse_transform(y_test)
# Out:
# 12/12 [==============================] - 1s 2ms/step

# %%
prediction[:5]
# Out:
# array([[ 98.51212],
#        [100.31564],
#        [ 99.64664],
#        [ 96.84549],
#        [ 96.19171]], dtype=float32)

# %%
# visualizing the results

plt.rcParams['figure.figsize'] = (15, 8)

plt.plot(y_test_inverse, color = 'red', label = 'Real  Stock ')
plt.plot(prediction, color = 'green', label = 'Predicted  Stock ')
plt.title('Final Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
rmse = mean_squared_error(y_test_inverse, prediction, squared=False)
print("rmse : ",rmse)
# Out:
# rmse :  4.819486384753071
