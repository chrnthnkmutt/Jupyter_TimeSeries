# %% [markdown]
# #Import data and library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import matplotlib.dates as mates
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.models import Sequential #helps to create model, layer by layer.
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error
# Out:
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Replace 'your_file_path.csv' with the path to your local CSV file
dataset_train = pd.read_csv('NSE-TATAGLOBAL.csv')
#stock_data = dataset_train.iloc[:, 1:2].values

# %% [markdown]
# #Data analytic

# %%
dataset_train.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
training_data = dataset_train.iloc[:, 5:6]
training_data.head()
# Out:
#     Close
# 0  233.75
# 1  233.25
# 2  234.25
# 3  236.10
# 4  233.30

# %%
import matplotlib.pylab as plt
plt.figure(figsize=(10,5))
plt.plot(training_data, color ='green');
plt.ylabel('Stock Price')
plt.title('Google Stock Price')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# #Min Max Scaler

# %%
# Normalize the training data between [0,1]
#the fit method, when applied to the training dataset, learns the model parameters (for example, mean and standard deviation).
#We then need to apply the transform method on the training dataset to get the transformed (scaled) training dataset.
#We could also perform both of this step in one step by applying fit_transform on the training dataset.
mm = MinMaxScaler(feature_range = (0, 1))
training_data_scaled = mm.fit_transform(training_data)
training_data_scaled.shape
# Out:
# (2035, 1)

# %%
plt.figure(figsize=(10,5))
plt.plot(training_data_scaled)
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.show()

# %% [markdown]
# #Prepare data for model training

# %%
# Getting the inputs and outputs directly if you know how to consider the past data for the number of time stamps needed for RNN.
x_train = training_data_scaled[59:training_data_scaled.shape[0]-1-365]
y_train = training_data_scaled[60:training_data_scaled.shape[0]-365]
x_test = training_data_scaled[training_data_scaled.shape[0]-1-365:-1]
y_test = training_data_scaled[training_data_scaled.shape[0]-365:]
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1610, 1)
# (1610, 1)
# (365, 1)
# (365, 1)

# %%
# reshaping
x_train = np.reshape(x_train, (x_train.shape[0],1,1))
print(x_train.shape)
# Out:
# (1610, 1, 1)

# %% [markdown]
# #Model Creation

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50,return_sequences = True,input_shape = (x_train.shape[1],1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
regressor.compile(optimizer = 'adam',loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
regressor.fit(x_train,y_train,epochs = 200, batch_size = 32)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\boatc\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 51/51 [==============================] - 7s 6ms/step - loss: 0.0726
# Epoch 2/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0240
# Epoch 3/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0061
# Epoch 4/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 5/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 6/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 7/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0025
# Epoch 8/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 9/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 10/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 11/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 12/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 13/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 14/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 15/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 16/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 17/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 18/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 19/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 20/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 21/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 22/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 23/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 24/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 25/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 26/200
# 51/51 [==============================] - 0s 6ms/step - loss: 9.8703e-04
# Epoch 27/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 28/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 29/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 30/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 31/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 32/200
# 51/51 [==============================] - 0s 6ms/step - loss: 9.0132e-04
# Epoch 33/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 34/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 35/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 36/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.7930e-04
# Epoch 37/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 38/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 39/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 40/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 41/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.8029e-04
# Epoch 42/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 43/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.6579e-04
# Epoch 44/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.6077e-04
# Epoch 45/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 46/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.1047e-04
# Epoch 47/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.5929e-04
# Epoch 48/200
# 51/51 [==============================] - 0s 6ms/step - loss: 9.0162e-04
# Epoch 49/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 50/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.9861e-04
# Epoch 51/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.3732e-04
# Epoch 52/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.6691e-04
# Epoch 53/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.9512e-04
# Epoch 54/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.3144e-04
# Epoch 55/200
# 51/51 [==============================] - 0s 5ms/step - loss: 9.1651e-04
# Epoch 56/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.8969e-04
# Epoch 57/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.4830e-04
# Epoch 58/200
# 51/51 [==============================] - 0s 6ms/step - loss: 9.5030e-04
# Epoch 59/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9.7298e-04
# Epoch 60/200
# 51/51 [==============================] - 0s 4ms/step - loss: 9
200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3437e-04
# Epoch 146/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.8830e-04
# Epoch 147/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.9309e-04
# Epoch 148/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.5652e-04
# Epoch 149/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.0061e-04
# Epoch 150/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.0383e-04
# Epoch 151/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5151e-04
# Epoch 152/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.2319e-04
# Epoch 153/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.8814e-04
# Epoch 154/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.9387e-04
# Epoch 155/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.6269e-04
# Epoch 156/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3102e-04
# Epoch 157/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.1514e-04
# Epoch 158/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.8128e-04
# Epoch 159/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.4054e-04
# Epoch 160/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.4884e-04
# Epoch 161/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.3999e-04
# Epoch 162/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.2699e-04
# Epoch 163/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.6131e-04
# Epoch 164/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.0141e-04
# Epoch 165/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.7160e-04
# Epoch 166/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.1703e-04
# Epoch 167/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.7719e-04
# Epoch 168/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.7923e-04
# Epoch 169/200
# 51/51 [==============================] - 0s 6ms/step - loss: 7.3525e-04
# Epoch 170/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.7733e-04
# Epoch 171/200
# 51/51 [==============================] - 0s 6ms/step - loss: 8.3549e-04
# Epoch 172/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.7237e-04
# Epoch 173/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3556e-04
# Epoch 174/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.6513e-04
# Epoch 175/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3818e-04
# Epoch 176/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5131e-04
# Epoch 177/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.5899e-04
# Epoch 178/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5146e-04
# Epoch 179/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.1249e-04
# Epoch 180/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.6642e-04
# Epoch 181/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.6927e-04
# Epoch 182/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.6962e-04
# Epoch 183/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.6899e-04
# Epoch 184/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.9572e-04
# Epoch 185/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.7200e-04
# Epoch 186/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5253e-04
# Epoch 187/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.2071e-04
# Epoch 188/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.0323e-04
# Epoch 189/200
# 51/51 [==============================] - 0s 6ms/step - loss: 7.7600e-04
# Epoch 190/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.3751e-04
# Epoch 191/200
# 51/51 [==============================] - 0s 6ms/step - loss: 7.3310e-04
# Epoch 192/200
# 51/51 [==============================] - 0s 4ms/step - loss: 7.5404e-04
# Epoch 193/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.1789e-04
# Epoch 194/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.2868e-04
# Epoch 195/200
# 51/51 [==============================] - 0s 6ms/step - loss: 7.3575e-04
# Epoch 196/200
# 51/51 [==============================] - 0s 5ms/step - loss: 8.0886e-04
# Epoch 197/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.5532e-04
# Epoch 198/200
# 51/51 [==============================] - 0s 5ms/step - loss: 6.7608e-04
# Epoch 199/200
# 51/51 [==============================] - 0s 5ms/step - loss: 7.1178e-04
# Epoch 200/200
# 51/51 [==============================] - 0s 4ms/step - loss: 6.7772e-04

# %% [markdown]
# #Prediction and Evaluation

# %%
input_value = np.reshape(x_test, (x_test.shape[0], 1, 1))

# %%
prediction = regressor.predict(input_value)
prediction = mm.inverse_transform(prediction)
y_test_inverse = mm.inverse_transform(y_test)
# Out:
# 12/12 [==============================] - 1s 3ms/step

# %%
prediction[:5]
# Out:
# array([[ 98.67541 ],
#        [100.487206],
#        [ 99.8151  ],
#        [ 97.0014  ],
#        [ 96.3448  ]], dtype=float32)

# %%
# visualizing the results

plt.rcParams['figure.figsize'] = (15, 8)

plt.plot(y_test_inverse, color = 'red', label = 'Real  Stock ')
plt.plot(prediction, color = 'green', label = 'Predicted  Stock ')
plt.title('Final Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
rmse = mean_squared_error(y_test_inverse, prediction, squared=False)
print("rmse : ",rmse)
# Out:
# rmse :  4.957092600714989
